# %% [markdown]
# <a href="https://colab.research.google.com/github/SamPetkov/PartialCoalescence/blob/main/DekaInerntal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# Constants + Time variables

# %%
#Constants
sigma12 = 22e-3
rho_l = 786.
Mu_l = 0.00105

D0 = 1.07e-3
Oh0 = Mu_l/np.sqrt(rho_l*sigma12*D0)


TAU = np.sqrt((rho_l*D0**(3))/(sigma12))
V0 = np.pi/6

#Results
Di = np.array([0,0.10,0.20,0.30,0.40,0.50,0.55,0.56])*D0
t_pinch_off_Deka_12 = np.array([0.860-0.320,0.905-0.380,0.822-0.284,0.849-0.323,0.806-0.282,0.890-0.391,0.890-0.380,0.899-0.385])
t_pinch_off_SI = t_pinch_off_Deka_12*TAU
t_pinch_off_Deka_11 = np.array([0.801-0.258,0.800-0.255,0.802-0.260,0.872-0.347,0.733-0.191,0.755-0.222,0.799-0.268,0.756-0.160])
# Di t_p di
dekaExtracted = np.array([
    [0.00, 1.59, 0.595],
    [0.10, 1.58, 0.602],
    [0.20, 1.58, 0.599],
    [0.30, 1.58, 0.603],
    [0.40, 1.58, 0.598],
    [0.50, 1.63, 0.608],
    [0.55, 1.70, 0.596],
    [0.56, 1.89, 0.595]
])

# %%
t_pinch_off_contact= np.array([0.551, 0.551,0.549,0.544,0.535,0.528,0.533,0.541])

# %%
# prompt: create a log-log plot of the dependence of t_pinch_off_D on D add a linear regression fit to the model

import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress



# Create the plot
plt.figure()
plt.plot(Di[:len(t_pinch_off_Deka_12)]/D0, t_pinch_off_Deka_12*2**(3/2), 'o', label='0.01D')
plt.plot(Di/D0,dekaExtracted[:,1], '^-k', label ='Deka')
plt.plot(Di/D0,t_pinch_off_contact*2**(3/2), '*',label='Contact')
#Style
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['DejaVu Serif', 'Times New Roman', 'Computer Modern Roman'] # Better font
plt.rcParams['mathtext.fontset'] = 'cm' # Use Computer Modern fonts for math
plt.rcParams['font.size'] = 10 # Adjust font size
plt.rcParams['axes.labelsize'] = 14  # Increased label size
plt.rcParams['axes.labelweight'] = 'bold' # Made labels bold
plt.rcParams['axes.titlesize'] = 12
plt.rcParams['xtick.labelsize'] = 9
plt.rcParams['ytick.labelsize'] = 9
plt.rcParams['legend.fontsize'] = 10
plt.rcParams['figure.titlesize'] = 12

plt.xlabel('$d_i$')
plt.ylabel('$t_p$')
plt.grid(False)
plt.tick_params(which='major', length=7, direction='in')
plt.tick_params(which='minor', length=4, direction='in')
plt.ylim(1.4, 1.9) # Changed y-axis limit
plt.legend()
plt.show()

# print(f"Linear regression slope: {slope:.4f}")
# print(f"Linear regression intercept: {intercept:.4f}")
# print(f"R-squared: {r_value**2:.4f}")

# %%
# prompt: create a log-log plot of the dependence of t_pinch_off_D on D add a linear regression fit to the model

import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress



# Create the plot
plt.figure()
plt.plot(Di[:len(t_pinch_off_Deka_12)]/D0, t_pinch_off_Deka_12*2**(3/2) /np.sqrt(1-(Di[:len(t_pinch_off_Deka_12)]/D0)**3), 'o', label='$\delta = 0.01D$ , $\Delta = 0.0024$')
plt.plot(Di[:len(t_pinch_off_Deka_11)]/D0, t_pinch_off_Deka_11*2**(3/2) /np.sqrt(1-(Di[:len(t_pinch_off_Deka_11)]/D0)**3), 's', label='$\delta = 0.01D$ , $\Delta = 0.0048$, Removing small bubbles ')
plt.plot(Di/D0,dekaExtracted[:,1], '^-k', label ='Deka, $\Delta = 0.006$')
plt.plot(Di/D0,t_pinch_off_contact*2**(3/2)/np.sqrt(1-(Di/D0)**3), '*',label='$\delta = 0$, $\Delta = 0.0024$')
#Style
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['DejaVu Serif', 'Times New Roman', 'Computer Modern Roman'] # Better font
plt.rcParams['mathtext.fontset'] = 'cm' # Use Computer Modern fonts for math
plt.rcParams['font.size'] = 12 # Adjust font size
plt.rcParams['axes.labelsize'] = 16  # Increased label size
plt.rcParams['axes.labelweight'] = 'bold' # Made labels bold
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['legend.fontsize'] = 12
plt.rcParams['figure.titlesize'] = 18

plt.xlabel('$d_i$')
plt.ylabel('$t_p^*$')
plt.grid(False)
plt.tick_params(which='major', length=7, direction='in')
plt.tick_params(which='minor', length=4, direction='in')
plt.ylim(1.4, 1.9) # Changed y-axis limit
plt.legend()
plt.savefig('tpcompare.pdf')
plt.show()

# print(f"Linear regression slope: {slope:.4f}")
# print(f"Linear regression intercept: {intercept:.4f}")
# print(f"R-squared: {r_value**2:.4f}")
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\d'
# <>:12: SyntaxWarning: invalid escape sequence '\d'
# <>:13: SyntaxWarning: invalid escape sequence '\D'
# <>:14: SyntaxWarning: invalid escape sequence '\d'
# <>:11: SyntaxWarning: invalid escape sequence '\d'
# <>:12: SyntaxWarning: invalid escape sequence '\d'
# <>:13: SyntaxWarning: invalid escape sequence '\D'
# <>:14: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-1016398051.py:11: SyntaxWarning: invalid escape sequence '\d'
#   plt.plot(Di[:len(t_pinch_off_Deka_12)]/D0, t_pinch_off_Deka_12*2**(3/2) /np.sqrt(1-(Di[:len(t_pinch_off_Deka_12)]/D0)**3), 'o', label='$\delta = 0.01D$ , $\Delta = 0.0024$')
# /tmp/ipython-input-1016398051.py:12: SyntaxWarning: invalid escape sequence '\d'
#   plt.plot(Di[:len(t_pinch_off_Deka_11)]/D0, t_pinch_off_Deka_11*2**(3/2) /np.sqrt(1-(Di[:len(t_pinch_off_Deka_11)]/D0)**3), 's', label='$\delta = 0.01D$ , $\Delta = 0.0048$, Removing small bubbles ')
# /tmp/ipython-input-1016398051.py:13: SyntaxWarning: invalid escape sequence '\D'
#   plt.plot(Di/D0,dekaExtracted[:,1], '^-k', label ='Deka, $\Delta = 0.006$')
# /tmp/ipython-input-1016398051.py:14: SyntaxWarning: invalid escape sequence '\d'
#   plt.plot(Di/D0,t_pinch_off_contact*2**(3/2)/np.sqrt(1-(Di/D0)**3), '*',label='$\delta = 0$, $\Delta = 0.0024$')

# %% [markdown]
# Diameter ratio

# %%
V_12 = np.array([0.0907435,0.0868174,0.0935802,0.0922508,0.0918565,0.0798903,0.0735073,0.0713509])
V_11 = np.array([0.100167,0.101224,0.097509,0.0879134,0.0985839,0.0920643,0.0814667,0.086751])
# 0.0907435,0.0868174
# Note - for gird level 10 we fractional pixels have a substantial effect on the volume calculaed
V = V0*(1-(Di/D0)**3)
D_Deka_12 = np.cbrt(V_12/V[:len(V_12)])
D_Deka_11 = np.cbrt(V_11/V[:len(V_11)])

d_Oh = np.cbrt(1-(3/8)*(Oh0+np.sqrt(Oh0**2+4)))

# %%
print(D_Deka_12 )
print(t_pinch_off_Deka_12)
print(t_pinch_off_SI)
# Out:
# [0.55753521 0.54955887 0.5647955  0.56574348 0.57228427 0.55867914
#  0.55223048 0.5488122 ]
# [0.54  0.525 0.538 0.526 0.524 0.499 0.51  0.514]
# [0.00357248 0.00347324 0.00355924 0.00347986 0.00346663 0.00330123
#  0.00337401 0.00340047]

# %%
error_from_frame_selection = 0.001/(np.sqrt(3)*0.551)

# %%
# prompt: create the matplot lib of D-daughter against Oh with points and draw the graph of d_Oh against Oh with continuos lines on the same graph start all arrays from index 2

V1 = np.array([0.105545,0.10583,0.105111,0.10414,0.102482,0.0976142,0.0906251,0.0884968])
V = V0*(1-(Di/D0)**3)
D_Contact= np.cbrt(V1/V[:len(V1)])

import matplotlib.pyplot as plt
plt.figure()
plt.plot(Di[:len(D_Deka_12)]/D0, D_Deka_12, 'o', label='$\delta  = 0.01D$, $\Delta = 0.0024$')
plt.plot(Di[:len(D_Deka_11)]/D0, D_Deka_11, 's', label='$\delta = 0.01D$, $\Delta = 0.0048$, Removing small bubbles')
plt.plot(Di/D0,dekaExtracted[:,2], '^-k', label ='Deka, $\Delta = 0.006$')
plt.plot(Di/D0,D_Contact, '*',label='$\delta = 0$, $\Delta = 0.0024$')
#Style
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['DejaVu Serif', 'Times New Roman', 'Computer Modern Roman'] # Better font
plt.rcParams['mathtext.fontset'] = 'cm' # Use Computer Modern fonts for math
plt.rcParams['font.size'] = 12 # Adjust font size
plt.rcParams['axes.labelsize'] = 16  # Increased label size
plt.rcParams['axes.labelweight'] = 'bold' # Made labels bold
plt.rcParams['axes.titlesize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['legend.fontsize'] = 12
plt.rcParams['figure.titlesize'] = 18
plt.tick_params(which='major', length=7, direction='in')
plt.tick_params(which='minor', length=4, direction='in')

plt.xlabel('$d_i$')
plt.ylabel('$d$')
plt.grid(False)
plt.legend()
plt.savefig('dicompare.pdf')
plt.show()
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\d'
# <>:10: SyntaxWarning: invalid escape sequence '\d'
# <>:11: SyntaxWarning: invalid escape sequence '\D'
# <>:12: SyntaxWarning: invalid escape sequence '\d'
# <>:9: SyntaxWarning: invalid escape sequence '\d'
# <>:10: SyntaxWarning: invalid escape sequence '\d'
# <>:11: SyntaxWarning: invalid escape sequence '\D'
# <>:12: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-1211535155.py:9: SyntaxWarning: invalid escape sequence '\d'
#   plt.plot(Di[:len(D_Deka_12)]/D0, D_Deka_12, 'o', label='$\delta  = 0.01D$, $\Delta = 0.0024$')
# /tmp/ipython-input-1211535155.py:10: SyntaxWarning: invalid escape sequence '\d'
#   plt.plot(Di[:len(D_Deka_11)]/D0, D_Deka_11, 's', label='$\delta = 0.01D$, $\Delta = 0.0048$, Removing small bubbles')
# /tmp/ipython-input-1211535155.py:11: SyntaxWarning: invalid escape sequence '\D'
#   plt.plot(Di/D0,dekaExtracted[:,2], '^-k', label ='Deka, $\Delta = 0.006$')
# /tmp/ipython-input-1211535155.py:12: SyntaxWarning: invalid escape sequence '\d'
#   plt.plot(Di/D0,D_Contact, '*',label='$\delta = 0$, $\Delta = 0.0024$')

# %% [markdown]
# error graphs

# %% [markdown]
#  tp

# %% [markdown]
# d di

# %% [markdown]
# Interface generator

# %%
file_path = '/content/INterface/10/drop_t_00.354.dat'  # your file location
background_image = '/content/INterface/10/time-00.354.png' # your image location

# Read the file and extract segments
segments = []
current_segment = []

with open(file_path, 'r') as file:
    for line in file:
        stripped = line.strip()
        if not stripped:
            if current_segment:
                segments.append(current_segment)
                current_segment = []
        else:
            try:
                x, y = map(float, stripped.split())
                current_segment.append((x, y))
            except ValueError:
                continue

# Append the last segment if it exists
if current_segment:
    segments.append(current_segment)

# Plot the segments
plt.figure(figsize=(8, 6))
for segment in segments:
    xs, ys = zip(*segment)
    # Plot original segment with swapped x and y
    plt.plot(ys, xs, color='purple', linewidth=.25)

    # Mirror the y-coordinates around x=0 (which are now the new x-coordinates)
    # and plot the mirrored segment with swapped x and y
    ys_mirrored = [-y for y in ys]
    plt.plot(ys_mirrored, xs, color='purple', linewidth=.33)


# Load and display the original background image
img = plt.imread(background_image)
plt.imshow(img, zorder=0, extent=[-2.6, 2.6, 4.4, 9.6])

plt.title("Interface of the Pool (Original and Mirrored around X=0) with Swapped Axes")
plt.xlabel("Y* Coordinate") # Swapped axis label
plt.ylabel("X* Coordinate") # Swapped axis label
plt.grid(True)
#plt.axis("equal")
plt.xlim(-3, 3)  # Set x-axis limits
plt.ylim(4, 10)  # Set y-axis limits
plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-28-154192873.py in <cell line: 0>()
#       6 current_segment = []
#       7
# ----> 8 with open(file_path, 'r') as file:
#       9     for line in file:
#      10         stripped = line.strip()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/INterface/10/drop_t_00.354.dat'

# %%
file_path = '/content/INterface/10/drop_t_00.354.dat'  # your file location
background_image = '/content/INterface/10/time-00.354.png' # your image location

# Read the file and extract segments
segments = []
current_segment = []

with open(file_path, 'r') as file:
    for line in file:
        stripped = line.strip()
        if not stripped:
            if current_segment:
                segments.append(current_segment)
                current_segment = []
        else:
            try:
                x, y = map(float, stripped.split())
                current_segment.append((x, y))
            except ValueError:
                continue
inch-off process of a secondary drop in the c
# Append the last segment if it exists
if current_segment:
    segments.append(current_segment)

# Plot the segments
plt.figure(figsize=(8, 6))
for segment in segments:
    xs, ys = zip(*segment)
    # Plot original segment with swapped x and y
    plt.plot(ys, xs, color='purple', linewidth=.25)

    # Mirror the y-coordinates around x=0 (which are now the new x-coordinates)
    # and plot the mirrored segment with swapped x and y
    ys_mirrored = [-y for y in ys]
    plt.plot(ys_mirrored, xs, color='purple', linewidth=.25)


# Load and display the original background image
img = plt.imread(background_image)
plt.imshow(img, zorder=0, extent=[-2.6, 2.6, 4.4, 9.6])

plt.title("Interface of the Pool (Original and Mirrored around X=0) with Swapped Axes")
plt.xlabel("Y* Coordinate") # Swapped axis label
plt.ylabel("X* Coordinate") # Swapped axis label
plt.grid(True)
#plt.axis("equal")
plt.xlim(-3, 3)  # Set x-axis limits
plt.ylim(4, 10)  # Set y-axis limits
plt.tight_layout()

plt.show()
